# %% [markdown]
# # Import

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from typing import Dict, Tuple
import torch

# %% [markdown]
# # Data

# %%
# Feature dictionary(fundamental feature)

path = r'h:\我的雲端硬碟\DEV_INTERN_ALPHA_DATA-20240709T015049Z-001\DEV_INTERN_ALPHA_DATA\pmart.parquet'
df = pd.read_parquet(path)
pmart_column_lst = df.columns.tolist()[2:]
pmart_data_dict = {}

pmart_column_lst = df.columns.tolist()[2:]
pmart_column_lst = [col for col in pmart_column_lst if col not in ['季別', '合併(Y/N)', '單季(Q)/單半年(H)', '月份', '幣別', '近一週報酬率(%)', '近一月報酬率(%)', '近一季報酬率(%)', '近一年報酬率(%)']]

for column in pmart_column_lst:
    temp_df = df[['datetime', 'symbol' , column]]
    pmart_data_dict[column] = temp_df.pivot_table(
    index='datetime',  # 行索引
    columns='symbol',  # 列名稱
    values=column,  # 數值
)
    
industry_path = r"C:\Users\User\Desktop\quant\Sector Allocation Framework under Reinforcement Learning Rotation\industry-rotation\security_properties.parquet"
property_data = pd.read_parquet(industry_path)

property_data = property_data.reset_index()
property_data = property_data[property_data['industry'].notna()]
symbol_to_industry = property_data[['symbol', 'industry']].set_index('symbol')['industry']

# 創建一個新 dictionary，用於儲存轉換後的 DataFrame
industry_data_dict = {}

for key, df in pmart_data_dict.items():
    # 重設 DataFrame 的列索引，將 symbol 映射為 industry
    df = df.rename(columns=symbol_to_industry).copy()
    
    # 基於 industry 聚合，計算平均值
    df = df.groupby(axis=1, level=0).mean()
    
    # 儲存到新的 dictionary
    industry_data_dict[key] = df

# 結果：industry_data_dict 包含的 DataFrame 是基於產業的全平均

feature_dict = pd.DataFrame()

# 合併多個df以符合RL所需格式
def reorganize_industry_data(industry_data_dict):
    """
    重組產業指標數據，將產業作為第一層，指標作為第二層
    
    Parameters:
    industry_data_dict: Dict[str, pd.DataFrame] - 指標資料字典，key為指標名稱
    
    Returns:
    pd.DataFrame - 重組後的DataFrame，MultiIndex為(產業, 指標)
    """
    # 取得所有日期作為索引
    all_dates = set()
    for df in industry_data_dict.values():
        all_dates.update(df.index)
    all_dates = sorted(list(all_dates))
    
    # 取得所有產業名稱
    industries = industry_data_dict[list(industry_data_dict.keys())[0]].columns
    
    # 創建新的DataFrame
    result_dict = {}
    
    # 重組數據
    for industry in industries:
        for indicator, df in industry_data_dict.items():
            if industry in df.columns:
                # 使用元組作為鍵，第一層是產業，第二層是指標
                result_dict[(industry, indicator)] = df[industry]
    
    # 創建最終的DataFrame
    result_df = pd.DataFrame(result_dict, index=all_dates)
    
    # 確保MultiIndex格式正確
    result_df.columns = pd.MultiIndex.from_tuples(result_df.columns)
    
    return result_df

# Fundamental feature

fundamental_lst = [
    "每股盈餘",
    "ROA(C) 稅前息前折舊前",  # 資產報酬率
    "ROE(A)-稅後",  # 股東權益報酬率
    "營業毛利率",
    "營業利益率",
    "稅後淨利率",
    "流動比率",
    "速動比率",
    "負債比率",
    "長期資金適合率(A)",
    "CFO/負債",
    "CFO/合併總損益",
    "現金流量比率",
    "營收成長率",
    "營業毛利成長率",
    "營業利益成長率"
]

fundamental_dict = {key: industry_data_dict[key] for key in fundamental_lst if key in industry_data_dict}

fundamental_feature = reorganize_industry_data(fundamental_dict)
fundamental_feature
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_5832\3269719251.py:34: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(axis=1, level=0).mean()
#                  光電業                                                           \
#                 每股盈餘 ROA(C) 稅前息前折舊前 ROE(A)-稅後      營業毛利率      營業利益率     稅後淨利率
# 2013-05-15  0.227706       1.739083 -0.308349   9.020000  -9.252569 -7.825413
# 2013-05-16  0.227706       1.739083 -0.308349   9.020000  -9.252569 -7.825413
# 2013-05-17  0.227706       1.739083 -0.308349   9.020000  -9.252569 -7.825413
# 2013-05-20  0.227706       1.739083 -0.308349   9.020000  -9.252569 -7.825413
# 2013-05-21  0.227706       1.739083 -0.308349   9.020000  -9.252569 -7.825413
# ...              ...            ...       ...        ...        ...       ...
# 2024-06-13  3.347071       6.278384  2.638788  17.876162 -11.568788  1.539798
# 2024-06-14  3.347071       6.278384  2.638788  17.876162 -11.568788  1.539798
# 2024-06-17  3.347071       6.278384  2.638788  17.876162 -11.568788  1.539798
# 2024-06-18  3.347071       6.278384  2.638788  17.876162 -11.568788  1.539798
# 2024-06-19  3.347071       6.278384  2.638788  17.876162 -11.568788  1.539798
#
#                                                             ...    食品工業  \
#                   流動比率        速動比率       負債比率   長期資金適合率(A)  ...    流動比率
# 2013-05-15  193.289083  138.493853  42.542385   277.254312  ...  273.83
# 2013-05-16  193.289083  138.493853  42.542385   277.254312  ...  273.83
# 2013-05-17  193.289083  138.493853  42.542385   277.254312  ...  273.83
# 2013-05-20  193.289083  138.493853  42.542385   277.254312  ...  273.83
# 2013-05-21  193.289083  138.493853  42.542385   277.254312  ...  273.83
# ...                ...         ...        ...          ...  ...     ...
# 2024-06-13  354.024747  296.764545  35.277677  2662.809091  ...  261.11
# 2024-06-14  354.024747  296.764545  35.277677  2662.809091  ...  261.11
# 2024-06-17  354.024747  296.764545  35.277677  2662.809091  ...  261.11
# 2024-06-18  354.024747  296.764545  35.277677  2662.809091  ...  261.11
# 2024-06-19  354.024747  296.764545  35.277677  2662.809091  ...  261.11
#
#                                                                               \
#                   速動比率       負債比率 長期資金適合率(A)    CFO/負債  CFO/合併總損益     現金流量比率
# 2013-05-15  191.565417  39.332917  307.09125  0.181579  31.411053  13.037083
# 2013-05-16  191.565417  39.332917  307.09125  0.181579  31.411053  13.037083
# 2013-05-17  191.565417  39.332917  307.09125  0.181579  31.411053  13.037083
# 2013-05-20  191.565417  39.332917  307.09125  0.181579  31.411053  13.037083
# 2013-05-21  191.565417  39.332917  307.09125  0.181579  31.411053  13.037083
# ...                ...        ...        ...       ...        ...        ...
# 2024-06-13  182.222500  36.582500  255.92250  0.320000   1.542500  12.059167
# 2024-06-14  182.222500  36.582500  255.92250  0.320000   1.542500  12.059167
# 2024-06-17  182.222500  36.582500  255.92250  0.320000   1.542500  12.059167
# 2024-06-18  182.222500  36.582500  255.92250  0.320000   1.542500  12.059167
# 2024-06-19  182.222500  36.582500  255.92250  0.320000   1.542500  12.059167
#
#
#                 營收成長率   營業毛利成長率      營業利益成長率
# 2013-05-15   5.011667 -27.79625  1613.193333
# 2013-05-16   5.011667 -27.79625  1613.193333
# 2013-05-17   5.011667 -27.79625  1613.193333
# 2013-05-20   5.011667 -27.79625  1613.193333
# 2013-05-21   5.011667 -27.79625  1613.193333
# ...               ...       ...          ...
# 2024-06-13  17.015000  29.99625    34.852083
# 2024-06-14  17.015000  29.99625    34.852083
# 2024-06-17  17.015000  29.99625    34.852083
# 2024-06-18  17.015000  29.99625    34.852083
# 2024-06-19  17.015000  29.99625    34.852083
#
# [2716 rows x 398 columns]

# %%
industry_data_dict.keys()
# Out:
# dict_keys(['融資買進(張)', '融資賣出(張)', '融券買入(張)', '融券賣出(張)', '融資餘額(張)', '融券餘額(張)', '融資餘額(千元)', '融券餘額(千元)', '融資使用率', '融券使用率', '券資比', '融資維持率', '融券維持率', '整戶維持率', '日報酬率(%)', '開盤價', '最高價', '最低價', '收盤價', '成交量(千股)', '交易所本益比', '流通股數(千股)', '交易所淨值市價比', '現金股利率', '開盤價-除權息', '最高價-除權息', '最低價-除權息', '收盤價-除權息', '外資買賣超(千股)', '投信買賣超(千股)', '自營買賣超(千股)', '合計買賣超(千股)', '外資買進張數', '投信買進張數', '外資賣出張數', '投信賣出張數', '自營買進張數', '自營賣出張數', '外資總持股數(千股)', '投信總持股數(千股)', '自營總持股數(千股)', '外資總持股率(%)', '投信總持股率(%)', '自營總持股率(%)', '單月營收(千元)', '去年單月營收(千元)', '單月營收成長率%', '累積營收(千元)', '去年累積營收(千元)', '累積營收成長率(%)', '每股盈餘', 'ROA(C) 稅前息前折舊前', 'ROE(A)-稅後', '營業毛利率', '營業利益率', '稅後淨利率', 'CFO/負債', 'CFO/合併總損益', '現金流量比率', '每股淨值(F)-TSE公告數', '營收成長率', '營業毛利成長率', '營業利益成長率', '流動比率', '速動比率', '負債比率', '長期資金適合率(A)', '應收帳款週轉次數', '總資產週轉次數', '存貨週轉率(次)', '應收帳款及票據', '存貨', '流動資產', '採權益法之長期股權投資', '不動產廠房及設備', '商譽及無形資產合計', '非流動資產', '資產總額', '短期借款', '應付商業本票∕承兌匯票', '一年內到期長期負債', '流動負債', '應付公司債－非流動', '銀行借款－非流動', '其他長期借款－非流動', '非流動負債', '負債總額', '股本', '保留盈餘', '股東權益總額', '負債及股東權益總額', '營業收入淨額', '營業成本', '營業毛利', '營業費用', '營業利益', '營業外收入及支出', '所得稅費用', '合併總損益', '歸屬母公司淨利（損）', '折舊－CFO', '攤提－CFO', '來自營運之現金流量', '投資活動之現金流量', '籌資活動之現金流量'])

# %%
# Feature lists
technical_lst = [
    "開盤價-除權息", "最高價-除權息", "最低價-除權息", "收盤價-除權息",
    "成交量(千股)", "交易所本益比", "交易所淨值市價比", "日報酬率(%)"
]

institutional_lst = [
    "外資買賣超(千股)", "投信買賣超(千股)", "自營買賣超(千股)",
    "外資總持股率(%)", "投信總持股率(%)", "自營總持股率(%)"
]

margin_lst = [
    "融資餘額(張)", "融券餘額(張)", "融資使用率", "融券使用率", "券資比"
]

# Create feature dictionaries
technical_dict = {key: industry_data_dict[key] for key in technical_lst if key in industry_data_dict}
institutional_dict = {key: industry_data_dict[key] for key in institutional_lst if key in industry_data_dict}
margin_dict = {key: industry_data_dict[key] for key in margin_lst if key in industry_data_dict}

# Add to feature_dict
price_volume_feature = reorganize_industry_data(technical_dict)
institutional_feature = reorganize_industry_data(institutional_dict)
margin_feature = reorganize_industry_data(margin_dict)

# %%
# return data
return_path = r'C:\Users\User\Desktop\quant\Sector Allocation Framework under Reinforcement Learning Rotation\industry-rotation\industryRL_v3\returns_data.csv'
return_data = pd.read_csv(return_path, index_col=0)
return_data
# Out:
#                  光電業        其他      化學工業       半導體      居家生活      建材營造  \
# datetime
# 2013-05-15  1.302608  0.642286  0.555994  0.421326  1.430424  1.199804
# 2013-05-16  1.185714 -0.036057  0.197428  0.836739  0.817339  0.699168
# 2013-05-17  1.512616  0.441230  0.179203  0.155004  0.421407  0.382724
# 2013-05-20  1.834277  0.620290  0.049575  0.013956  0.202222  0.684601
# 2013-05-21  1.433981  0.840786  0.208633  1.255811  0.770324  1.245729
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-13  0.902497  0.182257  0.061393  1.664595  0.060207 -0.052452
# 2024-06-14  1.033071  0.509263 -0.049464  0.548502  0.170418  1.386225
# 2024-06-17  0.965813  0.409280  0.470198  0.795250  0.170254 -1.090854
# 2024-06-18  0.166360  0.065814 -0.081207  0.735967 -0.106005  0.138477
# 2024-06-19 -0.474891  0.382039  0.360367 -0.544609 -0.009223 -0.048149
#
#                 數位雲端     文化創意業        材料      汽車工業  ...     資訊服務業     通信網路業  \
# datetime                                            ...
# 2013-05-15  0.832743  0.068016  0.975402  1.106733  ...  0.286967  0.635315
# 2013-05-16  2.735586  0.446837  0.767758  1.139428  ... -0.042337  0.187807
# 2013-05-17  3.806300  0.589184  0.117923  0.165011  ... -0.043563  0.443001
# 2013-05-20  1.009814 -0.270089  0.459767  0.013900  ...  0.825748  0.479855
# 2013-05-21  0.011843 -0.419305  0.657993  0.488272  ...  1.186656  0.174277
# ...              ...       ...       ...       ...  ...       ...       ...
# 2024-06-13  0.783233  0.289356 -0.222916  0.072225  ...  0.321056  0.448566
# 2024-06-14 -0.216948  0.644084  0.523718  0.100047  ...  0.002290  0.460051
# 2024-06-17  0.241833  1.275944  0.419556  0.200936  ...  0.059705  1.048089
# 2024-06-18  0.060600  0.002200  0.147713  0.468586  ... -0.034572  0.378672
# 2024-06-19  0.255829 -0.433460 -0.175336 -0.576589  ...  0.066177 -0.354962
#
#                  金融業      鋼鐵工業    電子商務     電子通路業     電子零組件      電機機械  \
# datetime
# 2013-05-15  1.274580  0.236545 -0.3968 -0.102849  0.512790  0.240838
# 2013-05-16  2.271045  0.364575  1.1952  0.554331  0.188547  0.507773
# 2013-05-17 -0.204555  0.104760  6.6929  0.521608  0.628443  0.076025
# 2013-05-20  0.919307  0.421353 -4.7970  0.774603  0.669102  0.433365
# 2013-05-21 -0.196455  1.180495 -0.7752  1.235131  0.763970  0.588637
# ...              ...       ...     ...       ...       ...       ...
# 2024-06-13  0.200614  0.201419     NaN  0.759009  0.579641  0.729533
# 2024-06-14  0.164769  0.224991     NaN  0.264346  0.740764  1.100432
# 2024-06-17  0.114348  0.559096     NaN  0.750651  0.612861  0.754979
# 2024-06-18  1.066314 -0.448411     NaN  0.825640 -0.011814  0.468741
# 2024-06-19  0.935398 -0.360645     NaN  0.184200 -0.683893 -0.778174
#
#                電腦及週邊      食品工業
# datetime
# 2013-05-15  0.603218  0.727992
# 2013-05-16  0.340185  0.243037
# 2013-05-17  0.577626  0.914350
# 2013-05-20  0.482416  0.439271
# 2013-05-21  0.942956  0.161783
# ...              ...       ...
# 2024-06-13  0.719946  0.022267
# 2024-06-14  0.616124  0.269683
# 2024-06-17  0.619787  0.263377
# 2024-06-18  0.118930  0.162933
# 2024-06-19 -0.440368  0.239840
#
# [2716 rows x 25 columns]

# %% [markdown]
# # Def

# %%
class SimpleIndustryEnv(gym.Env):
    def __init__(self, features_dict: Dict[str, pd.DataFrame], returns_data: pd.DataFrame):
        super().__init__()
        
        self.features_dict = self._process_features_dict(features_dict)
        self.returns_data = returns_data
        self.industry_names = list(returns_data.columns)  # Store column names as list
        self.n_industries = len(self.industry_names)
        self.total_features = sum(df.shape[1] for df in self.features_dict.values())
        
        self.action_space = spaces.Discrete(self.n_industries)
        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(self.total_features,),
            dtype=np.float32
        )
        
        self.current_step = 0
        
    def _process_features_dict(self, features_dict):
        processed = {}
        for key, df in features_dict.items():
            if isinstance(df.columns, pd.MultiIndex):
                df.columns = ['_'.join(map(str, col)).strip() for col in df.columns]
            processed[key] = df.fillna(0)
        return processed
    
    def _get_state(self) -> np.ndarray:
        current_date = self.returns_data.index[self.current_step]
        state = []
        
        for df in self.features_dict.values():
            values = df.loc[current_date].values
            values = np.nan_to_num(values, nan=0.0)
            state.extend(values)
            
        return np.array(state, dtype=np.float32)
    
    def step(self, action: int) -> Tuple[np.ndarray, float, bool, bool, dict]:
        next_returns = self.returns_data.iloc[self.current_step + 1]
        reward = float(next_returns.iloc[action])
        reward = np.nan_to_num(reward, nan=0.0)
        
        self.current_step += 1
        done = self.current_step >= len(self.returns_data) - 2
        
        return self._get_state(), reward, done, False, {}
    
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        return self._get_state(), {}

def train_and_predict(features_dict: Dict[str, pd.DataFrame], returns_data: pd.DataFrame,
                     train_size: int = 120, total_timesteps: int = 10000):
    returns_data = returns_data.fillna(0)
    
    train_features = {k: v.iloc[:train_size] for k, v in features_dict.items()}
    train_returns = returns_data.iloc[:train_size]
    test_returns = returns_data.iloc[train_size:]
    
    env = SimpleIndustryEnv(train_features, train_returns)
    
    model = PPO(
        'MlpPolicy', 
        env,
        verbose=0,
        device='cpu',
        policy_kwargs={'net_arch': [64, 64]}
    )
    
    model.learn(total_timesteps=total_timesteps)
    
    obs = env.reset()[0]
    predicted_industry_idx, _ = model.predict(obs, deterministic=True)
    
    # Calculate cumulative sum of returns for each industry
    test_returns_sum = test_returns.sum()
    
    # Convert integer index to industry name
    predicted_industry = env.industry_names[predicted_industry_idx]
    actual_best_industry = test_returns_sum.idxmax()
    
    predicted_return = float(test_returns_sum[predicted_industry])
    best_return = float(test_returns_sum.max())
    
    # Create result DataFrame
    result_df = pd.DataFrame({
        'train_start': [train_returns.index[0]],
        'train_end': [train_returns.index[-1]],
        'predict_start': [test_returns.index[0]],
        'predict_end': [test_returns.index[-1]],
        'predicted_industry': [predicted_industry],
        'actual_best_industry': [actual_best_industry],
        'predicted_return': [predicted_return],
        'best_return': [best_return],
        'prediction_accuracy': [predicted_industry == actual_best_industry],
        'return_difference': [predicted_return - best_return]
    })
    
    return result_df

# Helper function to check data quality
def check_data_quality(features_dict, returns_data):
    print("Returns Data Shape:", returns_data.shape)
    print("\nReturns Data NaN Count:\n", returns_data.isna().sum())
    
    print("\nFeatures Data:")
    for key, df in features_dict.items():
        print(f"\n{key} Shape:", df.shape)
        print(f"{key} NaN Count:\n", df.isna().sum())

# %%
def filter_ecommerce(features_dict, returns_data):
    # 過濾 returns_data
    non_ecommerce_returns = returns_data.drop(columns=[col for col in returns_data.columns 
                                                     if '電子商務' in col])
    
    # 過濾 features_dict
    non_ecommerce_features = {}
    for key, df in features_dict.items():
        # 移除包含電子商務的欄位
        filtered_cols = [col for col in df.columns if '電子商務' not in col]
        non_ecommerce_features[key] = df[filtered_cols]
    
    return non_ecommerce_features, non_ecommerce_returns

# %%
feature_dict = {}
feature_dict['fundamantal'] = fundamental_feature
feature_dict['price_volume'] = price_volume_feature
feature_dict['institutional'] = institutional_feature
feature_dict['margin'] = margin_feature

# %%
feature_dict, return_data = filter_ecommerce(feature_dict, return_data)

# %%
# 檢查數據質量
check_data_quality(feature_dict, return_data)
# Out:
# Returns Data Shape: (2716, 24)
#
# Returns Data NaN Count:
#  光電業      0
# 其他       0
# 化學工業     0
# 半導體      0
# 居家生活     0
# 建材營造     0
# 數位雲端     0
# 文化創意業    0
# 材料       0
# 汽車工業     0
# 油電燃氣業    0
# 生技醫療     0
# 綠能環保     0
# 航運業      0
# 觀光餐旅     0
# 資訊服務業    0
# 通信網路業    0
# 金融業      0
# 鋼鐵工業     0
# 電子通路業    0
# 電子零組件    0
# 電機機械     0
# 電腦及週邊    0
# 食品工業     0
# dtype: int64
#
# Features Data:
#
# fundamantal Shape: (2716, 384)
# fundamantal NaN Count:
#  光電業   每股盈餘              0
#       ROA(C) 稅前息前折舊前    0
#       ROE(A)-稅後         0
#       營業毛利率             0
#       營業利益率             0
#                        ..
# 食品工業  CFO/合併總損益         0
#       現金流量比率            0
#       營收成長率             0
#       營業毛利成長率           0
#       營業利益成長率           0
# Length: 384, dtype: int64
#
# price_volume Shape: (2716, 199)
# price_volume NaN Count:
#  光電業   開盤價-除權息     0
#       最高價-除權息     0
#       最低價-除權息     0
#       收盤價-除權息     0
#       成交量(千股)     0
#                  ..
# 食品工業  收盤價-除權息     0
#       成交量(千股)     0
#       交易所本益比      0
#       交易所淨值市價比    0
#       日報酬率(%)     0
# Length: 199, dtype: int64
#
# institutional Shape: (2716, 144)
# institutional NaN Count:
#  光電業   外資買賣超(千股)      0
#       投信買賣超(千股)      0
#       自營買賣超(千股)    385
#       外資總持股率(%)      0
#       投信總持股率(%)      0
#                   ...
# 食品工業  投信買賣超(千股)      0
#       自營買賣超(千股)    385
#       外資總持股率(%)      0
#       投信總持股率(%)      0
#       自營總持股率(%)      0
# Length: 144, dtype: int64
#
# margin Shape: (2716, 120)
# margin NaN Count:
#  光電業   融資餘額(張)    0
#       融券餘額(張)    0
#       融資使用率      0
#       融券使用率      0
#       券資比        0
#                 ..
# 食品工業  融資餘額(張)    0
#       融券餘額(張)    0
#       融資使用率      0
#       融券使用率      0
#       券資比        0
# Length: 120, dtype: int64

# %%
feature_dict['price_volume']
# Out:
#                   光電業                                                \
#               開盤價-除權息    最高價-除權息    最低價-除權息    收盤價-除權息      成交量(千股)
# 2013-05-15  38.338061  39.492214  37.916811  39.168114  5231.477477
# 2013-05-16  39.702303  40.700423  39.284958  40.027850  7570.450450
# 2013-05-17  40.242260  40.872673  39.729132  40.163731  5778.828829
# 2013-05-20  40.292846  40.885087  39.957044  40.371691  5169.423423
# 2013-05-21  40.790742  41.810965  40.352077  41.090105  6708.863636
# ...               ...        ...        ...        ...          ...
# 2024-06-13  76.152926  77.570976  74.858302  76.483032  3228.453573
# 2024-06-14  76.636168  79.070593  75.887609  78.345938  3304.080573
# 2024-06-17  78.514661  80.900019  77.560903  79.272297  5117.275573
# 2024-06-18  80.054041  81.280249  78.479703  79.768368  4295.904043
# 2024-06-19  80.301103  81.200676  78.505315  79.085641  4387.148718
#
#                                                   其他             ...  \
#                交易所本益比  交易所淨值市價比   日報酬率(%)    開盤價-除權息    最高價-除權息  ...
# 2013-05-15  26.436951  1.438829  1.302608  22.208871  22.510906  ...
# 2013-05-16  13.664512  1.439459  1.185714  22.256321  22.482913  ...
# 2013-05-17  13.828293  1.455045  1.512616  22.193600  22.525694  ...
# 2013-05-20  13.964634  1.474505  1.834277  22.209539  22.477294  ...
# 2013-05-21  14.258272  1.494182  1.433981  22.326261  22.587336  ...
# ...               ...       ...       ...        ...        ...  ...
# 2024-06-13  48.666711  2.199231  0.902497  56.568571  57.254729  ...
# 2024-06-14  49.063421  2.226154  1.033071  56.549145  57.381395  ...
# 2024-06-17  49.489868  2.244017  0.965813  56.794222  57.651378  ...
# 2024-06-18  49.741974  2.246410  0.166360  57.132520  57.791078  ...
# 2024-06-19  49.767105  2.228291 -0.474891  57.345349  58.097975  ...
#
#                電腦及週邊                 食品工業                                   \
#             交易所淨值市價比   日報酬率(%)    開盤價-除權息    最高價-除權息    最低價-除權息    收盤價-除權息
# 2013-05-15  1.619184  0.603218  19.883777  20.210362  19.746062  20.031823
# 2013-05-16  1.572245  0.340185  20.238015  20.390046  20.007123  20.207665
# 2013-05-17  1.581633  0.577626  20.361277  20.649112  20.287288  20.524538
# 2013-05-20  1.594082  0.482416  20.696750  20.924169  20.575650  20.784273
# 2013-05-21  1.613265  0.942956  20.931481  21.130842  20.737404  20.983454
# ...              ...       ...        ...        ...        ...        ...
# 2024-06-13  2.912818  0.719946  66.167333  66.588333  65.887000  66.231667
# 2024-06-14  2.935636  0.616124  66.231667  66.826667  66.093333  66.505000
# 2024-06-17  2.946545  0.619787  66.550667  66.867667  66.259000  66.600000
# 2024-06-18  2.951818  0.118930  66.653333  66.941667  66.383333  66.676000
# 2024-06-19  2.941000 -0.440368  66.716667  67.324333  66.360000  66.909000
#
#
#                 成交量(千股)     交易所本益比  交易所淨值市價比   日報酬率(%)
# 2013-05-15  1394.423077  28.724231  1.875385  0.727992
# 2013-05-16  1517.307692  24.910385  1.876923  0.243038
# 2013-05-17  1224.269231  25.174615  1.901538  0.914350
# 2013-05-20  1171.346154  25.365769  1.921923  0.439271
# 2013-05-21  1012.346154  25.483462  1.936923  0.161783
# ...                 ...        ...       ...       ...
# 2024-06-13   537.971300  27.588519  2.244000  0.022267
# 2024-06-14   507.765867  27.652963  2.252333  0.269683
# 2024-06-17   474.755633  27.735926  2.256000  0.263377
# 2024-06-18   694.784167  27.751481  2.258667  0.162933
# 2024-06-19   795.187033  27.858889  2.270000  0.239840
#
# [2716 rows x 199 columns]

# %%
return_data
# Out:
#                  光電業        其他      化學工業       半導體      居家生活      建材營造  \
# datetime
# 2013-05-15  1.302608  0.642286  0.555994  0.421326  1.430424  1.199804
# 2013-05-16  1.185714 -0.036057  0.197428  0.836739  0.817339  0.699168
# 2013-05-17  1.512616  0.441230  0.179203  0.155004  0.421407  0.382724
# 2013-05-20  1.834277  0.620290  0.049575  0.013956  0.202222  0.684601
# 2013-05-21  1.433981  0.840786  0.208633  1.255811  0.770324  1.245729
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-13  0.902497  0.182257  0.061393  1.664595  0.060207 -0.052452
# 2024-06-14  1.033071  0.509263 -0.049464  0.548502  0.170418  1.386225
# 2024-06-17  0.965813  0.409280  0.470198  0.795250  0.170254 -1.090854
# 2024-06-18  0.166360  0.065814 -0.081207  0.735967 -0.106005  0.138477
# 2024-06-19 -0.474891  0.382039  0.360367 -0.544609 -0.009223 -0.048149
#
#                 數位雲端     文化創意業        材料      汽車工業  ...      觀光餐旅     資訊服務業  \
# datetime                                            ...
# 2013-05-15  0.832743  0.068016  0.975402  1.106733  ...  0.702136  0.286967
# 2013-05-16  2.735586  0.446837  0.767758  1.139428  ...  0.188944 -0.042337
# 2013-05-17  3.806300  0.589184  0.117923  0.165011  ...  0.219496 -0.043563
# 2013-05-20  1.009814 -0.270089  0.459767  0.013900  ...  0.629604  0.825748
# 2013-05-21  0.011843 -0.419305  0.657993  0.488272  ...  0.478588  1.186656
# ...              ...       ...       ...       ...  ...       ...       ...
# 2024-06-13  0.783233  0.289356 -0.222916  0.072225  ...  0.305734  0.321056
# 2024-06-14 -0.216948  0.644084  0.523718  0.100047  ...  1.114505  0.002290
# 2024-06-17  0.241833  1.275944  0.419556  0.200936  ...  0.233298  0.059705
# 2024-06-18  0.060600  0.002200  0.147713  0.468586  ... -0.298798 -0.034572
# 2024-06-19  0.255829 -0.433460 -0.175336 -0.576589  ... -0.383461  0.066177
#
#                通信網路業       金融業      鋼鐵工業     電子通路業     電子零組件      電機機械  \
# datetime
# 2013-05-15  0.635315  1.274580  0.236545 -0.102849  0.512790  0.240838
# 2013-05-16  0.187807  2.271045  0.364575  0.554331  0.188547  0.507773
# 2013-05-17  0.443001 -0.204555  0.104760  0.521608  0.628443  0.076025
# 2013-05-20  0.479855  0.919307  0.421353  0.774603  0.669102  0.433365
# 2013-05-21  0.174277 -0.196455  1.180495  1.235131  0.763970  0.588637
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-13  0.448566  0.200614  0.201419  0.759009  0.579641  0.729533
# 2024-06-14  0.460051  0.164769  0.224991  0.264346  0.740764  1.100432
# 2024-06-17  1.048089  0.114348  0.559096  0.750651  0.612861  0.754979
# 2024-06-18  0.378672  1.066314 -0.448411  0.825640 -0.011814  0.468741
# 2024-06-19 -0.354962  0.935398 -0.360645  0.184200 -0.683893 -0.778174
#
#                電腦及週邊      食品工業
# datetime
# 2013-05-15  0.603218  0.727992
# 2013-05-16  0.340185  0.243037
# 2013-05-17  0.577626  0.914350
# 2013-05-20  0.482416  0.439271
# 2013-05-21  0.942956  0.161783
# ...              ...       ...
# 2024-06-13  0.719946  0.022267
# 2024-06-14  0.616124  0.269683
# 2024-06-17  0.619787  0.263377
# 2024-06-18  0.118930  0.162933
# 2024-06-19 -0.440368  0.239840
#
# [2716 rows x 24 columns]

# %% [markdown]
# # Train and predict

# %%
final = pd.DataFrame()  #to save all  prediction results
feature_dict['fundamantal'] = feature_dict['fundamantal'][16:]
feature_dict['price_volume'] = feature_dict['price_volume'][16:]
feature_dict['institutional'] = feature_dict['institutional'][16:]
feature_dict['margin'] = feature_dict['margin'][16:]
return_data = return_data[16:]
check_data_quality(feature_dict, return_data)
# Out:
# Returns Data Shape: (2700, 24)
#
# Returns Data NaN Count:
#  光電業      0
# 其他       0
# 化學工業     0
# 半導體      0
# 居家生活     0
# 建材營造     0
# 數位雲端     0
# 文化創意業    0
# 材料       0
# 汽車工業     0
# 油電燃氣業    0
# 生技醫療     0
# 綠能環保     0
# 航運業      0
# 觀光餐旅     0
# 資訊服務業    0
# 通信網路業    0
# 金融業      0
# 鋼鐵工業     0
# 電子通路業    0
# 電子零組件    0
# 電機機械     0
# 電腦及週邊    0
# 食品工業     0
# dtype: int64
#
# Features Data:
#
# fundamantal Shape: (2700, 384)
# fundamantal NaN Count:
#  光電業   每股盈餘              0
#       ROA(C) 稅前息前折舊前    0
#       ROE(A)-稅後         0
#       營業毛利率             0
#       營業利益率             0
#                        ..
# 食品工業  CFO/合併總損益         0
#       現金流量比率            0
#       營收成長率             0
#       營業毛利成長率           0
#       營業利益成長率           0
# Length: 384, dtype: int64
#
# price_volume Shape: (2700, 199)
# price_volume NaN Count:
#  光電業   開盤價-除權息     0
#       最高價-除權息     0
#       最低價-除權息     0
#       收盤價-除權息     0
#       成交量(千股)     0
#                  ..
# 食品工業  收盤價-除權息     0
#       成交量(千股)     0
#       交易所本益比      0
#       交易所淨值市價比    0
#       日報酬率(%)     0
# Length: 199, dtype: int64
#
# institutional Shape: (2700, 144)
# institutional NaN Count:
#  光電業   外資買賣超(千股)      0
#       投信買賣超(千股)      0
#       自營買賣超(千股)    369
#       外資總持股率(%)      0
#       投信總持股率(%)      0
#                   ...
# 食品工業  投信買賣超(千股)      0
#       自營買賣超(千股)    369
#       外資總持股率(%)      0
#       投信總持股率(%)      0
#       自營總持股率(%)      0
# Length: 144, dtype: int64
#
# margin Shape: (2700, 120)
# margin NaN Count:
#  光電業   融資餘額(張)    0
#       融券餘額(張)    0
#       融資使用率      0
#       融券使用率      0
#       券資比        0
#                 ..
# 食品工業  融資餘額(張)    0
#       融券餘額(張)    0
#       融資使用率      0
#       融券使用率      0
#       券資比        0
# Length: 120, dtype: int64

# %%
def rolling_train_predict(features_dict, returns_data, train_size=120, predict_size=30, total_timesteps=10000):
    """
    Implement rolling window prediction where each model is trained on train_size days 
    and predicts the next predict_size days.
    
    Args:
        features_dict: Dictionary of feature DataFrames
        returns_data: Returns DataFrame
        train_size: Number of days used for training
        predict_size: Number of days to predict ahead
        total_timesteps: Training iterations for PPO
    
    Returns:
        DataFrame containing all prediction results
    """
    
    all_predictions = []
    total_rows = len(returns_data)
    
    # 計算可以滾動的次數
    n_iterations = (total_rows - train_size - predict_size) // predict_size + 1
    
    print(f"總共需要執行 {n_iterations} 次預測")
    
    for i in range(n_iterations):
        print(f"正在執行第 {i+1}/{n_iterations} 次預測...")
        
        # 計算當前視窗的索引
        start_idx = i * predict_size
        train_end = start_idx + train_size
        
        # 選取當前視窗的訓練資料和預測區間
        current_features = {k: v.iloc[start_idx:train_end] for k, v in features_dict.items()}
        current_returns = returns_data.iloc[start_idx:train_end + predict_size]
        
        # 訓練和預測
        result_df = train_and_predict(
            current_features,
            current_returns,
            train_size=train_size,
            total_timesteps=total_timesteps
        )
        
        # 添加視窗資訊
        result_df['window_number'] = i
        result_df['window_start'] = start_idx
        result_df['window_end'] = train_end
        
        all_predictions.append(result_df)
        
        print(f"第 {i+1} 次預測完成")
    
    print("所有預測執行完畢！")
    
    # 合併所有預測結果
    if all_predictions:
        final_predictions = pd.concat(all_predictions, ignore_index=True)
        return final_predictions
    else:
        return pd.DataFrame()

# %%
# Usage example:
rolling_predictions = rolling_train_predict(feature_dict, return_data, 
                                         train_size=120, 
                                         predict_size=7,
                                         total_timesteps=10000)
# Out:
# 總共需要執行 368 次預測
# 正在執行第 1/368 次預測...
# 第 1 次預測完成
# 正在執行第 2/368 次預測...
# 第 2 次預測完成
# 正在執行第 3/368 次預測...
# 第 3 次預測完成
# 正在執行第 4/368 次預測...
# 第 4 次預測完成
# 正在執行第 5/368 次預測...
# 第 5 次預測完成
# 正在執行第 6/368 次預測...
# 第 6 次預測完成
# 正在執行第 7/368 次預測...
# 第 7 次預測完成
# 正在執行第 8/368 次預測...
# 第 8 次預測完成
# 正在執行第 9/368 次預測...
# 第 9 次預測完成
# 正在執行第 10/368 次預測...
# 第 10 次預測完成
# 正在執行第 11/368 次預測...
# 第 11 次預測完成
# 正在執行第 12/368 次預測...
# 第 12 次預測完成
# 正在執行第 13/368 次預測...
# 第 13 次預測完成
# 正在執行第 14/368 次預測...
# 第 14 次預測完成
# 正在執行第 15/368 次預測...
# 第 15 次預測完成
# 正在執行第 16/368 次預測...
# 第 16 次預測完成
# 正在執行第 17/368 次預測...
# 第 17 次預測完成
# 正在執行第 18/368 次預測...
# 第 18 次預測完成
# 正在執行第 19/368 次預測...
# 第 19 次預測完成
# 正在執行第 20/368 次預測...
# 第 20 次預測完成
# 正在執行第 21/368 次預測...
# 第 21 次預測完成
# 正在執行第 22/368 次預測...
# 第 22 次預測完成
# 正在執行第 23/368 次預測...
# 第 23 次預測完成
# 正在執行第 24/368 次預測...
# 第 24 次預測完成
# 正在執行第 25/368 次預測...
# 第 25 次預測完成
# 正在執行第 26/368 次預測...
# 第 26 次預測完成
# 正在執行第 27/368 次預測...
# 第 27 次預測完成
# 正在執行第 28/368 次預測...
# 第 28 次預測完成
# 正在執行第 29/368 次預測...
# 第 29 次預測完成
# 正在執行第 30/368 次預測...
# 第 30 次預測完成
# 正在執行第 31/368 次預測...
# 第 31 次預測完成
# 正在執行第 32/368 次預測...
# 第 32 次預測完成
# 正在執行第 33/368 次預測...
# 第 33 次預測完成
# 正在執行第 34/368 次預測...
# 第 34 次預測完成
# 正在執行第 35/368 次預測...
# 第 35 次預測完成
# 正在執行第 36/368 次預測...
# 第 36 次預測完成
# 正在執行第 37/368 次預測...
# 第 37 次預測完成
# 正在執行第 38/368 次預測...
# 第 38 次預測完成
# 正在執行第 39/368 次預測...
# 第 39 次預測完成
# 正在執行第 40/368 次預測...
# 第 40 次預測完成
# 正在執行第 41/368 次預測...
# 第 41 次預測完成
# 正在執行第 42/368 次預測...
# 第 42 次預測完成
# 正在執行第 43/368 次預測...
# 第 43 次預測完成
# 正在執行第 44/368 次預測...
# 第 44 次預測完成
# 正在執行第 45/368 次預測...
# 第 45 次預測完成
# 正在執行第 46/368 次預測...
# 第 46 次預測完成
# 正在執行第 47/368 次預測...
# 第 47 次預測完成
# 正在執行第 48/368 次預測...
# 第 48 次預測完成
# 正在執行第 49/368 次預測...
# 第 49 次預測完成
# 正在執行第 50/368 次預測...
# 第 50 次預測完成
# 正在執行第 51/368 次預測...
# 第 51 次預測完成
# 正在執行第 52/368 次預測...
# 第 52 次預測完成
# 正在執行第 53/368 次預測...
# 第 53 次預測完成
# 正在執行第 54/368 次預測...
# 第 54 次預測完成
# 正在執行第 55/368 次預測...
# 第 55 次預測完成
# 正在執行第 56/368 次預測...
# 第 56 次預測完成
# 正在執行第 57/368 次預測...
# 第 57 次預測完成
# 正在執行第 58/368 次預測...
# 第 58 次預測完成
# 正在執行第 59/368 次預測...
# 第 59 次預測完成
# 正在執行第 60/368 次預測...
# 第 60 次預測完成
# 正在執行第 61/368 次預測...
# 第 61 次預測完成
# 正在執行第 62/368 次預測...
# 第 62 次預測完成
# 正在執行第 63/368 次預測...
# 第 63 次預測完成
# 正在執行第 64/368 次預測...
# 第 64 次預測完成
# 正在執行第 65/368 次預測...
# 第 65 次預測完成
# 正在執行第 66/368 次預測...
# 第 66 次預測完成
# 正在執行第 67/368 次預測...
# 第 67 次預測完成
# 正在執行第 68/368 次預測...
# 第 68 次預測完成
# 正在執行第 69/368 次預測...
# 第 69 次預測完成
# 正在執行第 70/368 次預測...
# 第 70 次預測完成
# 正在執行第 71/368 次預測...
# 第 71 次預測完成
# 正在執行第 72/368 次預測...
# 第 72 次預測完成
# 正在執行第 73/368 次預測...
# 第 73 次預測完成
# 正在執行第 74/368 次預測...
# 第 74 次預測完成
# 正在執行第 75/368 次預測...
# 第 75 次預測完成
# 正在執行第 76/368 次預測...
# 第 76 次預測完成
# 正在執行第 77/368 次預測...
# 第 77 次預測完成
# 正在執行第 78/368 次預測...
# 第 78 次預測完成
# 正在執行第 79/368 次預測...
# 第 79 次預測完成
# 正在執行第 80/368 次預測...
# 第 80 次預測完成
# 正在執行第 81/368 次預測...
# 第 81 次預測完成
# 正在執行第 82/368 次預測...
# 第 82 次預測完成
# 正在執行第 83/368 次預測...
# 第 83 次預測完成
# 正在執行第 84/368 次預測...
# 第 84 次預測完成
# 正在執行第 85/368 次預測...
# 第 85 次預測完成
# 正在執行第 86/368 次預測...
# 第 86 次預測完成
# 正在執行第 87/368 次預測...
# 第 87 次預測完成
# 正在執行第 88/368 次預測...
# 第 88 次預測完成
# 正在執行第 89/368 次預測...
# 第 89 次預測完成
# 正在執行第 90/368 次預測...
# 第 90 次預測完成
# 正在執行第 91/368 次預測...
# 第 91 次預測完成
# 正在執行第 92/368 次預測...
# 第 92 次預測完成
# 正在執行第 93/368 次預測...
# 第 93 次預測完成
# 正在執行第 94/368 次預測...
# 第 94 次預測完成
# 正在執行第 95/368 次預測...
# 第 95 次預測完成
# 正在執行第 96/368 次預測...
# 第 96 次預測完成
# 正在執行第 97/368 次預測...
# 第 97 次預測完成
# 正在執行第 98/368 次預測...
# 第 98 次預測完成
# 正在執行第 99/368 次預測...
# 第 99 次預測完成
# 正在執行第 100/368 次預測...
# 第 100 次預測完成
# 正在執行第 101/368 次預測...
# 第 101 次預測完成
# 正在執行第 102/368 次預測...
# 第 102 次預測完成
# 正在執行第 103/368 次預測...
# 第 103 次預測完成
# 正在執行第 104/368 次預測...
# 第 104 次預測完成
# 正在執行第 105/368 次預測...
# 第 105 次預測完成
# 正在執行第 106/368 次預測...
# 第 106 次預測完成
# 正在執行第 107/368 次預測...
# 第 107 次預測完成
# 正在執行第 108/368 次預測...
# 第 108 次預測完成
# 正在執行第 109/368 次預測...
# 第 109 次預測完成
# 正在執行第 110/368 次預測...
# 第 110 次預測完成
# 正在執行第 111/368 次預測...
# 第 111 次預測完成
# 正在執行第 112/368 次預測...
# 第 112 次預測完成
# 正在執行第 113/368 次預測...
# 第 113 次預測完成
# 正在執行第 114/368 次預測...
# 第 114 次預測完成
# 正在執行第 115/368 次預測...
# 第 115 次預測完成
# 正在執行第 116/368 次預測...
# 第 116 次預測完成
# 正在執行第 117/368 次預測...
# 第 117 次預測完成
# 正在執行第 118/368 次預測...
# 第 118 次預測完成
# 正在執行第 119/368 次預測...
# 第 119 次預測完成
# 正在執行第 120/368 次預測...
# 第 120 次預測完成
# 正在執行第 121/368 次預測...
# 第 121 次預測完成
# 正在執行第 122/368 次預測...
# 第 122 次預測完成
# 正在執行第 123/368 次預測...
# 第 123 次預測完成
# 正在執行第 124/368 次預測...
# 第 124 次預測完成
# 正在執行第 125/368 次預測...
# 第 125 次預測完成
# 正在執行第 126/368 次預測...
# 第 126 次預測完成
# 正在執行第 127/368 次預測...
# 第 127 次預測完成
# 正在執行第 128/368 次預測...
# 第 128 次預測完成
# 正在執行第 129/368 次預測...
# 第 129 次預測完成
# 正在執行第 130/368 次預測...
# 第 130 次預測完成
# 正在執行第 131/368 次預測...
# 第 131 次預測完成
# 正在執行第 132/368 次預測...
# 第 132 次預測完成
# 正在執行第 133/368 次預測...
# 第 133 次預測完成
# 正在執行第 134/368 次預測...
# 第 134 次預測完成
# 正在執行第 135/368 次預測...
# 第 135 次預測完成
# 正在執行第 136/368 次預測...
# 第 136 次預測完成
# 正在執行第 137/368 次預測...
# 第 137 次預測完成
# 正在執行第 138/368 次預測...
# 第 138 次預測完成
# 正在執行第 139/368 次預測...
# 第 139 次預測完成
# 正在執行第 140/368 次預測...
# 第 140 次預測完成
# 正在執行第 141/368 次預測...
# 第 141 次預測完成
# 正在執行第 142/368 次預測...
# 第 142 次預測完成
# 正在執行第 143/368 次預測...
# 第 143 次預測完成
# 正在執行第 144/368 次預測...
# 第 144 次預測完成
# 正在執行第 145/368 次預測...
# 第 145 次預測完成
# 正在執行第 146/368 次預測...
# 第 146 次預測完成
# 正在執行第 147/368 次預測...
# 第 147 次預測完成
# 正在執行第 148/368 次預測...
# 第 148 次預測完成
# 正在執行第 149/368 次預測...
# 第 149 次預測完成
# 正在執行第 150/368 次預測...
# 第 150 次預測完成
# 正在執行第 151/368 次預測...
# 第 151 次預測完成
# 正在執行第 152/368 次預測...
# 第 152 次預測完成
# 正在執行第 153/368 次預測...
# 第 153 次預測完成
# 正在執行第 154/368 次預測...
# 第 154 次預測完成
# 正在執行第 155/368 次預測...
# 第 155 次預測完成
# 正在執行第 156/368 次預測...
# 第 156 次預測完成
# 正在執行第 157/368 次預測...
# 第 157 次預測完成
# 正在執行第 158/368 次預測...
# 第 158 次預測完成
# 正在執行第 159/368 次預測...
# 第 159 次預測完成
# 正在執行第 160/368 次預測...
# 第 160 次預測完成
# 正在執行第 161/368 次預測...
# 第 161 次預測完成
# 正在執行第 162/368 次預測...
# 第 162 次預測完成
# 正在執行第 163/368 次預測...
# 第 163 次預測完成
# 正在執行第 164/368 次預測...
# 第 164 次預測完成
# 正在執行第 165/368 次預測...
# 第 165 次預測完成
# 正在執行第 166/368 次預測...
# 第 166 次預測完成
# 正在執行第 167/368 次預測...
# 第 167 次預測完成
# 正在執行第 168/368 次預測...
# 第 168 次預測完成
# 正在執行第 169/368 次預測...
# 第 169 次預測完成
# 正在執行第 170/368 次預測...
# 第 170 次預測完成
# 正在執行第 171/368 次預測...
# 第 171 次預測完成
# 正在執行第 172/368 次預測...
# 第 172 次預測完成
# 正在執行第 173/368 次預測...
# 第 173 次預測完成
# 正在執行第 174/368 次預測...
# 第 174 次預測完成
# 正在執行第 175/368 次預測...
# 第 175 次預測完成
# 正在執行第 176/368 次預測...
# 第 176 次預測完成
# 正在執行第 177/368 次預測...
# 第 177 次預測完成
# 正在執行第 178/368 次預測...
# 第 178 次預測完成
# 正在執行第 179/368 次預測...
# 第 179 次預測完成
# 正在執行第 180/368 次預測...
# 第 180 次預測完成
# 正在執行第 181/368 次預測...
# 第 181 次預測完成
# 正在執行第 182/368 次預測...
# 第 182 次預測完成
# 正在執行第 183/368 次預測...
# 第 183 次預測完成
# 正在執行第 184/368 次預測...
# 第 184 次預測完成
# 正在執行第 185/368 次預測...
# 第 185 次預測完成
# 正在執行第 186/368 次預測...
# 第 186 次預測完成
# 正在執行第 187/368 次預測...
# 第 187 次預測完成
# 正在執行第 188/368 次預測...
# 第 188 次預測完成
# 正在執行第 189/368 次預測...
# 第 189 次預測完成
# 正在執行第 190/368 次預測...
# 第 190 次預測完成
# 正在執行第 191/368 次預測...
# 第 191 次預測完成
# 正在執行第 192/368 次預測...
# 第 192 次預測完成
# 正在執行第 193/368 次預測...
# 第 193 次預測完成
# 正在執行第 194/368 次預測...
# 第 194 次預測完成
# 正在執行第 195/368 次預測...
# 第 195 次預測完成
# 正在執行第 196/368 次預測...
# 第 196 次預測完成
# 正在執行第 197/368 次預測...
# 第 197 次預測完成
# 正在執行第 198/368 次預測...
# 第 198 次預測完成
# 正在執行第 199/368 次預測...
# 第 199 次預測完成
# 正在執行第 200/368 次預測...
# 第 200 次預測完成
# 正在執行第 201/368 次預測...
# 第 201 次預測完成
# 正在執行第 202/368 次預測...
# 第 202 次預測完成
# 正在執行第 203/368 次預測...
# 第 203 次預測完成
# 正在執行第 204/368 次預測...
# 第 204 次預測完成
# 正在執行第 205/368 次預測...
# 第 205 次預測完成
# 正在執行第 206/368 次預測...
# 第 206 次預測完成
# 正在執行第 207/368 次預測...
# 第 207 次預測完成
# 正在執行第 208/368 次預測...
# 第 208 次預測完成
# 正在執行第 209/368 次預測...
# 第 209 次預測完成
# 正在執行第 210/368 次預測...
# 第 210 次預測完成
# 正在執行第 211/368 次預測...
# 第 211 次預測完成
# 正在執行第 212/368 次預測...
# 第 212 次預測完成
# 正在執行第 213/368 次預測...
# 第 213 次預測完成
# 正在執行第 214/368 次預測...
# 第 214 次預測完成
# 正在執行第 215/368 次預測...
# 第 215 次預測完成
# 正在執行第 216/368 次預測...
# 第 216 次預測完成
# 正在執行第 217/368 次預測...
# 第 217 次預測完成
# 正在執行第 218/368 次預測...
# 第 218 次預測完成
# 正在執行第 219/368 次預測...
# 第 219 次預測完成
# 正在執行第 220/368 次預測...
# 第 220 次預測完成
# 正在執行第 221/368 次預測...
# 第 221 次預測完成
# 正在執行第 222/368 次預測...
# 第 222 次預測完成
# 正在執行第 223/368 次預測...
# 第 223 次預測完成
# 正在執行第 224/368 次預測...
# 第 224 次預測完成
# 正在執行第 225/368 次預測...
# 第 225 次預測完成
# 正在執行第 226/368 次預測...
# 第 226 次預測完成
# 正在執行第 227/368 次預測...
# 第 227 次預測完成
# 正在執行第 228/368 次預測...
# 第 228 次預測完成
# 正在執行第 229/368 次預測...
# 第 229 次預測完成
# 正在執行第 230/368 次預測...
# 第 230 次預測完成
# 正在執行第 231/368 次預測...
# 第 231 次預測完成
# 正在執行第 232/368 次預測...
# 第 232 次預測完成
# 正在執行第 233/368 次預測...
# 第 233 次預測完成
# 正在執行第 234/368 次預測...
# 第 234 次預測完成
# 正在執行第 235/368 次預測...
# 第 235 次預測完成
# 正在執行第 236/368 次預測...
# 第 236 次預測完成
# 正在執行第 237/368 次預測...
# 第 237 次預測完成
# 正在執行第 238/368 次預測...
# 第 238 次預測完成
# 正在執行第 239/368 次預測...
# 第 239 次預測完成
# 正在執行第 240/368 次預測...
# 第 240 次預測完成
# 正在執行第 241/368 次預測...
# 第 241 次預測完成
# 正在執行第 242/368 次預測...
# 第 242 次預測完成
# 正在執行第 243/368 次預測...
# 第 243 次預測完成
# 正在執行第 244/368 次預測...
# 第 244 次預測完成
# 正在執行第 245/368 次預測...
# 第 245 次預測完成
# 正在執行第 246/368 次預測...
# 第 246 次預測完成
# 正在執行第 247/368 次預測...
# 第 247 次預測完成
# 正在執行第 248/368 次預測...
# 第 248 次預測完成
# 正在執行第 249/368 次預測...
# 第 249 次預測完成
# 正在執行第 250/368 次預測...
# 第 250 次預測完成
# 正在執行第 251/368 次預測...
# 第 251 次預測完成
# 正在執行第 252/368 次預測...
# 第 252 次預測完成
# 正在執行第 253/368 次預測...
# 第 253 次預測完成
# 正在執行第 254/368 次預測...
# 第 254 次預測完成
# 正在執行第 255/368 次預測...
# 第 255 次預測完成
# 正在執行第 256/368 次預測...
# 第 256 次預測完成
# 正在執行第 257/368 次預測...
# 第 257 次預測完成
# 正在執行第 258/368 次預測...
# 第 258 次預測完成
# 正在執行第 259/368 次預測...
# 第 259 次預測完成
# 正在執行第 260/368 次預測...
# 第 260 次預測完成
# 正在執行第 261/368 次預測...
# 第 261 次預測完成
# 正在執行第 262/368 次預測...
# 第 262 次預測完成
# 正在執行第 263/368 次預測...
# 第 263 次預測完成
# 正在執行第 264/368 次預測...
# 第 264 次預測完成
# 正在執行第 265/368 次預測...
# 第 265 次預測完成
# 正在執行第 266/368 次預測...
# 第 266 次預測完成
# 正在執行第 267/368 次預測...
# 第 267 次預測完成
# 正在執行第 268/368 次預測...
# 第 268 次預測完成
# 正在執行第 269/368 次預測...
# 第 269 次預測完成
# 正在執行第 270/368 次預測...
# 第 270 次預測完成
# 正在執行第 271/368 次預測...
# 第 271 次預測完成
# 正在執行第 272/368 次預測...
# 第 272 次預測完成
# 正在執行第 273/368 次預測...
# 第 273 次預測完成
# 正在執行第 274/368 次預測...
# 第 274 次預測完成
# 正在執行第 275/368 次預測...
# 第 275 次預測完成
# 正在執行第 276/368 次預測...
# 第 276 次預測完成
# 正在執行第 277/368 次預測...
# 第 277 次預測完成
# 正在執行第 278/368 次預測...
# 第 278 次預測完成
# 正在執行第 279/368 次預測...
# 第 279 次預測完成
# 正在執行第 280/368 次預測...
# 第 280 次預測完成
# 正在執行第 281/368 次預測...
# 第 281 次預測完成
# 正在執行第 282/368 次預測...
# 第 282 次預測完成
# 正在執行第 283/368 次預測...
# 第 283 次預測完成
# 正在執行第 284/368 次預測...
# 第 284 次預測完成
# 正在執行第 285/368 次預測...
# 第 285 次預測完成
# 正在執行第 286/368 次預測...
# 第 286 次預測完成
# 正在執行第 287/368 次預測...
# 第 287 次預測完成
# 正在執行第 288/368 次預測...
# 第 288 次預測完成
# 正在執行第 289/368 次預測...
# 第 289 次預測完成
# 正在執行第 290/368 次預測...
# 第 290 次預測完成
# 正在執行第 291/368 次預測...
# 第 291 次預測完成
# 正在執行第 292/368 次預測...
# 第 292 次預測完成
# 正在執行第 293/368 次預測...
# 第 293 次預測完成
# 正在執行第 294/368 次預測...
# 第 294 次預測完成
# 正在執行第 295/368 次預測...
# 第 295 次預測完成
# 正在執行第 296/368 次預測...
# 第 296 次預測完成
# 正在執行第 297/368 次預測...
# 第 297 次預測完成
# 正在執行第 298/368 次預測...
# 第 298 次預測完成
# 正在執行第 299/368 次預測...
# 第 299 次預測完成
# 正在執行第 300/368 次預測...
# 第 300 次預測完成
# 正在執行第 301/368 次預測...
# 第 301 次預測完成
# 正在執行第 302/368 次預測...
# 第 302 次預測完成
# 正在執行第 303/368 次預測...
# 第 303 次預測完成
# 正在執行第 304/368 次預測...
# 第 304 次預測完成
# 正在執行第 305/368 次預測...
# 第 305 次預測完成
# 正在執行第 306/368 次預測...
# 第 306 次預測完成
# 正在執行第 307/368 次預測...
# 第 307 次預測完成
# 正在執行第 308/368 次預測...
# 第 308 次預測完成
# 正在執行第 309/368 次預測...
# 第 309 次預測完成
# 正在執行第 310/368 次預測...
# 第 310 次預測完成
# 正在執行第 311/368 次預測...
# 第 311 次預測完成
# 正在執行第 312/368 次預測...
# 第 312 次預測完成
# 正在執行第 313/368 次預測...
# 第 313 次預測完成
# 正在執行第 314/368 次預測...
# 第 314 次預測完成
# 正在執行第 315/368 次預測...
# 第 315 次預測完成
# 正在執行第 316/368 次預測...
# 第 316 次預測完成
# 正在執行第 317/368 次預測...
# 第 317 次預測完成
# 正在執行第 318/368 次預測...
# 第 318 次預測完成
# 正在執行第 319/368 次預測...
# 第 319 次預測完成
# 正在執行第 320/368 次預測...
# 第 320 次預測完成
# 正在執行第 321/368 次預測...
# 第 321 次預測完成
# 正在執行第 322/368 次預測...
# 第 322 次預測完成
# 正在執行第 323/368 次預測...
# 第 323 次預測完成
# 正在執行第 324/368 次預測...
# 第 324 次預測完成
# 正在執行第 325/368 次預測...
# 第 325 次預測完成
# 正在執行第 326/368 次預測...
# 第 326 次預測完成
# 正在執行第 327/368 次預測...
# 第 327 次預測完成
# 正在執行第 328/368 次預測...
# 第 328 次預測完成
# 正在執行第 329/368 次預測...
# 第 329 次預測完成
# 正在執行第 330/368 次預測...
# 第 330 次預測完成
# 正在執行第 331/368 次預測...
# 第 331 次預測完成
# 正在執行第 332/368 次預測...
# 第 332 次預測完成
# 正在執行第 333/368 次預測...
# 第 333 次預測完成
# 正在執行第 334/368 次預測...
# 第 334 次預測完成
# 正在執行第 335/368 次預測...
# 第 335 次預測完成
# 正在執行第 336/368 次預測...
# 第 336 次預測完成
# 正在執行第 337/368 次預測...
# 第 337 次預測完成
# 正在執行第 338/368 次預測...
# 第 338 次預測完成
# 正在執行第 339/368 次預測...
# 第 339 次預測完成
# 正在執行第 340/368 次預測...
# 第 340 次預測完成
# 正在執行第 341/368 次預測...
# 第 341 次預測完成
# 正在執行第 342/368 次預測...
# 第 342 次預測完成
# 正在執行第 343/368 次預測...
# 第 343 次預測完成
# 正在執行第 344/368 次預測...
# 第 344 次預測完成
# 正在執行第 345/368 次預測...
# 第 345 次預測完成
# 正在執行第 346/368 次預測...
# 第 346 次預測完成
# 正在執行第 347/368 次預測...
# 第 347 次預測完成
# 正在執行第 348/368 次預測...
# 第 348 次預測完成
# 正在執行第 349/368 次預測...
# 第 349 次預測完成
# 正在執行第 350/368 次預測...
# 第 350 次預測完成
# 正在執行第 351/368 次預測...
# 第 351 次預測完成
# 正在執行第 352/368 次預測...
# 第 352 次預測完成
# 正在執行第 353/368 次預測...
# 第 353 次預測完成
# 正在執行第 354/368 次預測...
# 第 354 次預測完成
# 正在執行第 355/368 次預測...
# 第 355 次預測完成
# 正在執行第 356/368 次預測...
# 第 356 次預測完成
# 正在執行第 357/368 次預測...
# 第 357 次預測完成
# 正在執行第 358/368 次預測...
# 第 358 次預測完成
# 正在執行第 359/368 次預測...
# 第 359 次預測完成
# 正在執行第 360/368 次預測...
# 第 360 次預測完成
# 正在執行第 361/368 次預測...
# 第 361 次預測完成
# 正在執行第 362/368 次預測...
# 第 362 次預測完成
# 正在執行第 363/368 次預測...
# 第 363 次預測完成
# 正在執行第 364/368 次預測...
# 第 364 次預測完成
# 正在執行第 365/368 次預測...
# 第 365 次預測完成
# 正在執行第 366/368 次預測...
# 第 366 次預測完成
# 正在執行第 367/368 次預測...
# 第 367 次預測完成
# 正在執行第 368/368 次預測...
# 第 368 次預測完成
# 所有預測執行完畢！

# %%
rolling_predictions.to_csv('rolling_predictions4.csv', index=False)

# %%
# 計算 False 的比例
false_count = rolling_predictions["prediction_accuracy"].value_counts()[False]
total_count = rolling_predictions["prediction_accuracy"].count()
false_ratio = false_count / total_count

print(f"False 的比例為: {false_ratio:.2%}")
# Out:
# False 的比例為: 94.84%
