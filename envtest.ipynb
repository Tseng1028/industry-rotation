# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 創建 CartPole 環境，並使用 DummyVecEnv 將其向量化
env = DummyVecEnv([lambda: gym.make("CartPole-v1")])

# 創建 PPO 模型
model = PPO("MlpPolicy", env, verbose=1, device="auto")  # "auto" 自動檢測 GPU 或 CPU

# 訓練模型
model.learn(total_timesteps=10000)

# 測試模型
obs = env.reset()  # 直接返回 NumPy 數組
for _ in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()  # 渲染 CartPole 動作畫面
    if done.any():  # 對向量化環境檢查是否完成
        obs = env.reset()
# Out:
# Using cuda device
# -----------------------------
# | time/              |      |
# |    fps             | 806  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009147419 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00224     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.27        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 50.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009304794 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0973      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 42.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 572        |
# |    iterations           | 4          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00874312 |
# |    clip_fraction        | 0.0796     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.639     |
# |    explained_variance   | 0.214      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.8       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0188    |
# |    value_loss           | 58.5       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 5            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0073970538 |
# |    clip_fraction        | 0.0633       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.613       |
# |    explained_variance   | 0.26         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0153      |
# |    value_loss           | 69.1         |
# ------------------------------------------
# c:\Users\User\.conda\envs\PPORL\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
